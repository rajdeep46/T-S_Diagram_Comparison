# %%
# %reset -f
from numpy import *
import matplotlib.pyplot as PT
import CoolProp.CoolProp as CP
from tabulate import tabulate
plt=PT.subplots()

P1=float(input("enter the pressure at point 1:"))
T1=float(input("enter the Temp at point 1:"))
S1=CP.PropsSI('S', 'T', T1, 'P', P1, 'water')
#print(S1)
H1=CP.PropsSI('H', 'T', T1, 'P', P1, 'water')
D1=CP.PropsSI('D', 'P', P1, 'T', T1, 'water')
SV1 = 1/D1
Q1=CP.PropsSI('Q', 'T', T1, 'S', S1, 'water')
print(Q1)
#print(D1)
#print(SV1)
#print(H1)

S2=S1/.90
P2=float(input("enter the pressure at point 2:"))
T2=CP.PropsSI('T', 'S', S2, 'P', P2, 'water')
#print(T2)
H2=CP.PropsSI('H', 'T', T2, 'P', P2, 'water')
D2=CP.PropsSI('D', 'P', P2, 'T', T2, 'water')
SV2 = 1/D2
#print(D2)
#print(SV2)
#print(H2)

P3=P2
S3=CP.PropsSI('S', 'Q', 0, 'P', P3, 'water')
#print(S3)
T3=CP.PropsSI('T', 'S', S3, 'P', P3, 'water')
#print(T3)
H3=CP.PropsSI('H', 'T', T3, 'Q', 0, 'water') #note
D3=CP.PropsSI('D', 'Q', 0, 'T', T3, 'water') #note
SV3 = 1/D3
#print(D3)
#print(H3)

P4=P3
T4=T3
S4=CP.PropsSI('S', 'T', T4, 'Q', 1, 'water')
#print(S4)
H4=CP.PropsSI('H', 'T', T4, 'Q', 1, 'water')
D4=CP.PropsSI('D', 'P', P4, 'Q', 1, 'water')
SV4 = 1/D4
#print(D1)
#print(SV1)
#print(H4)

P5=P4
T5=float(input("enter the temp at point 5:"))
S5=CP.PropsSI('S', 'T', T5, 'P', P4, 'water')
#print(S5)
H5=CP.PropsSI('H', 'T', T5, 'P', P5, 'water')
D5=CP.PropsSI('D', 'P', P5, 'T', T5, 'water')
SV5 = 1/D5
#print(H5)

S6=S5/.90
P6=P1
T6=T1
#print(P6)
H6=CP.PropsSI('H', 'S', S6, 'P', P6, 'water')
D6=CP.PropsSI('D', 'P', P6, 'T', T6, 'water')
SV6 = 1/D6
#print(D6)
#print(H6)

print(tabulate([["1",T1,P1,S1,H1,D1,SV1],["2",T2,P2,S2,H2,D2,SV2],["3",T3,P3,S3,H3,D3,SV3],["4",T4,P4,S4,H4,D4,SV4],["5",T5,P5,S5,H5,D5,SV5],["6",T6,P6,S6,H6,D6,SV6]], headers=["Step","temperature","pressure","entropy","enthalpy","density","specfic_gravity"]))

print("--------------------------------------------------------------")

#inputs from excell.
N_P=.70
N_T=.85
HS2=1121228
HS1=882479
msdot=.2

WS=msdot*(HS2-HS1)
mdot=(WS/(H6-H2))
Wp=mdot*(H2-H1)/(N_P*3)
Wt=mdot*(H5-H2)*N_T/3
W=Wt-Wp
H_DELTA=H6-H2
H_DELTA_S=HS2-HS1
total_fuel_energy=861966.35
nom_power=310000
New_power=W+nom_power
nic=(nom_power/total_fuel_energy)*100
n_ic_orc=(New_power/total_fuel_energy)*100
FRP=(1-(nic/n_ic_orc))*100

print("enthalpy deference 6-2=",H_DELTA)
print("enthalpy deference heat source=",H_DELTA_S)
print("work input=",WS)
print("--------------------------------------------------------------")
print("mdot=",mdot)
print("turbine work=",Wt)
print("pump work=",Wp)
print("cycle work=",W)
print("--------------------------------------------------------------")
n=(W/WS)*100
print("cycle efficiency=",n,"%")
print("combined power=",New_power)
print("--------------------------------------------------------------")
print("efficency of engine=",nic)
print("efficency of engine with orc=",n_ic_orc)
print("Fuel Reduction Percentage=",FRP)

P1a=float(input("enter the pressure at point 1a:"))
T1a=float(input("enter the Temp at point 1a:"))
S1a=CP.PropsSI('S', 'T', T1a, 'P', P1a, 'water')
#print(S1)
H1a=CP.PropsSI('H', 'T', T1a, 'P', P1a, 'water')
D1a=CP.PropsSI('D', 'P', P1a, 'T', T1a, 'water')
SV1a = 1/D1a
Q1a=CP.PropsSI('Q', 'T', T1a, 'S', S1a, 'water')
print(Q1a)
#print(D1)
#print(SV1)
#print(H1)

S2a=S1a/.90
P2a=float(input("enter the pressure at point 2a:"))
T2a=CP.PropsSI('T', 'S', S2a, 'P', P2a, 'water')
#print(T2)
H2a=CP.PropsSI('H', 'T', T2a, 'P', P2a, 'water')
D2a=CP.PropsSI('D', 'P', P2a, 'T', T2a, 'water')
SV2a = 1/D2a
#print(D2)
#print(SV2)
#print(H2)

P3a=P2a
S3a=CP.PropsSI('S', 'Q', 0, 'P', P3a, 'water')
#print(S3)
T3a=CP.PropsSI('T', 'S', S3a, 'P', P3a, 'water')
#print(T3)
H3a=CP.PropsSI('H', 'T', T3a, 'Q', 0, 'water') #note
D3a=CP.PropsSI('D', 'Q', 0, 'T', T3a, 'water') #note
SV3a = 1/D3a
#print(D3)
#print(H3)

P4a=P3a
T4a=T3a
S4a=CP.PropsSI('S', 'T', T4a, 'Q', 1, 'water')
#print(S4)
H4a=CP.PropsSI('H', 'T', T4a, 'Q', 1, 'water')
D4a=CP.PropsSI('D', 'P', P4a, 'Q', 1, 'water')
SV4a = 1/D4a
#print(D1)
#print(SV1)
#print(H4)

P5a=P4a
T5a=float(input("enter the temp at point 5:"))
S5a=CP.PropsSI('S', 'T', T5a, 'P', P4a, 'water')
#print(S5)
H5a=CP.PropsSI('H', 'T', T5a, 'P', P5a, 'water')
D5a=CP.PropsSI('D', 'P', P5a, 'T', T5a, 'water')
SV5a = 1/D5a
#print(H5)

S6a=S5a/.90
P6a=P1a
T6a=T1a
#print(P6)
H6a=CP.PropsSI('H', 'S', S6a, 'P', P6a, 'water')
D6a=CP.PropsSI('D', 'P', P6a, 'T', T6a, 'water')
SV6a = 1/D6a
#print(D6)
#print(H6)

print(tabulate([["1",T1a,P1a,S1a,H1a,D1a,SV1a],["2",T2a,P2a,S2a,H2a,D2a,SV2a],["3",T3a,P3a,S3a,H3a,D3a,SV3a],["4",T4a,P4a,S4a,H4a,D4a,SV4a],["5",T5a,P5a,S5a,H5a,D5a,SV5a],["6",T6a,P6a,S6a,H6a,D6a,SV6a]], headers=["Step","temperature","pressure","entropy","enthalpy","density","specfic_gravity"]))

print("--------------------------------------------------------------")

#inputs from excell.
N_Pa=.70
N_Ta=.85
HS2a=1121228
HS1a=882479
msdota=.2

WSa=msdota*(HS2a-HS1a)
mdota=(WSa/(H6a-H2a))
Wpa=mdota*(H2a-H1a)/(N_Pa*3)
Wta=mdota*(H5a-H2a)*N_Ta/3
Wa=Wta-Wpa
H_DELTAa=H6a-H2a
H_DELTA_Sa=HS2a-HS1a
total_fuel_energya=861966.35
nom_powera=310000
New_powera=Wa+nom_powera
nica=(nom_powera/total_fuel_energya)*100
n_ic_orca=(New_powera/total_fuel_energya)*100
FRPa=(1-(nica/n_ic_orca))*100

print("enthalpy deference 6-2=",H_DELTAa)
print("enthalpy deference heat source=",H_DELTA_Sa)
print("work input=",WSa)
print("--------------------------------------------------------------")
print("mdot=",mdota)
print("turbine work=",Wta)
print("pump work=",Wpa)
print("cycle work=",Wa)
print("--------------------------------------------------------------")
na=(Wa/WSa)*100
print("cycle efficiency=",na,"%")
print("combined power=",New_powera)
print("--------------------------------------------------------------")
print("efficency of engine=",nica)
print("efficency of engine with orc=",n_ic_orca)
print("Fuel Reduction Percentage=",FRPa)
     
x=[S1,S2,S3,S4,S5,S6,S1]
y=[T1,T2,T3,T4,T5,T6,T1]
PT.plot(x,y,marker='o',color='green',)
PT.ylim(273.15,800)
PT.xlim(0,10000)
PT.xlabel('ENTROPY')
PT.ylabel('TEMPERATURE')
PT.title('TS-Diagram')

xa=[S1a,S2a,S3a,S4a,S5a,S6a,S1a]
ya=[T1a,T2a,T3a,T4a,T5a,T6a,T1a]
PT.plot(xa,y,marker='o',color='blue', linestyle='dashed')
#PT.ylim(273.15,800)
#PT.xlim(0,10000)
#PT.xlabel('ENTROPY')
#PT.ylabel('TEMPERATURE')
#PT.title('TS-Diagram')


P1b=float(input("enter the pressure at point 1b:"))
T1b=float(input("enter the Temp at point 1b:"))
S1b=CP.PropsSI('S', 'T', T1b, 'P', P1b, 'water')
#print(S1)
H1b=CP.PropsSI('H', 'T', T1b, 'P', P1b, 'water')
D1b=CP.PropsSI('D', 'P', P1b, 'T', T1b, 'water')
SV1b = 1/D1b
Q1b=CP.PropsSI('Q', 'T', T1b, 'S', S1b, 'water')
print(Q1b)
#print(D1)
#print(SV1)
#print(H1)

S2b=S1b/.90
P2b=float(input("enter the pressure at point 2:"))
T2b=CP.PropsSI('T', 'S', S2b, 'P', P2b, 'water')
#print(T2)
H2b=CP.PropsSI('H', 'T', T2b, 'P', P2b, 'water')
D2b=CP.PropsSI('D', 'P', P2b, 'T', T2b, 'water')
SV2b = 1/D2b
#print(D2)
#print(SV2)
#print(H2)

P3b=P2b
S3b=CP.PropsSI('S', 'Q', 0, 'P', P3b, 'water')
#print(S3)
T3b=CP.PropsSI('T', 'S', S3b, 'P', P3b, 'water')
#print(T3)
H3b=CP.PropsSI('H', 'T', T3b, 'Q', 0, 'water') #note
D3b=CP.PropsSI('D', 'Q', 0, 'T', T3b, 'water') #note
SV3b = 1/D3b
#print(D3)
#print(H3)

P4b=P3b
T4b=T3b
S4b=CP.PropsSI('S', 'T', T4b, 'Q', 1, 'water')
#print(S4)
H4b=CP.PropsSI('H', 'T', T4b, 'Q', 1, 'water')
D4b=CP.PropsSI('D', 'P', P4b, 'Q', 1, 'water')
SV4b = 1/D4b
#print(D1)
#print(SV1)
#print(H4)

P5b=P4b
T5b=float(input("enter the temp at point 5:"))
S5b=CP.PropsSI('S', 'T', T5b, 'P', P4b, 'water')
#print(S5)
H5b=CP.PropsSI('H', 'T', T5b, 'P', P5b, 'water')
D5b=CP.PropsSI('D', 'P', P5b, 'T', T5b, 'water')
SV5b = 1/D5b
#print(H5)

S6b=S5b/.90
P6b=P1b
T6b=T1b
#print(P6)
H6b=CP.PropsSI('H', 'S', S6b, 'P', P6b, 'water')
D6b=CP.PropsSI('D', 'P', P6b, 'T', T6b, 'water')
SV6b = 1/D6b
#print(D6)
#print(H6)

print(tabulate([["1",T1b,P1b,S1b,H1b,D1b,SV1b],["2",T2b,P2b,S2b,H2b,D2b,SV2b],["3",T3b,P3b,S3b,H3b,D3b,SV3b],["4",T4b,P4b,S4b,H4b,D4b,SV4b],["5",T5b,P5b,S5b,H5b,D5b,SV5b],["6",T6b,P6b,S6b,H6b,D6b,SV6b]], headers=["Step","temperature","pressure","entropy","enthalpy","density","specfic_gravity"]))

print("--------------------------------------------------------------")

#inputs from excell.
N_Pb=.70
N_Tb=.85
HS2b=1121228
HS1b=882479
msdotb=.2

WSb=msdotb*(HS2b-HS1b)
mdotb=(WSb/(H6b-H2b))
Wpb=mdotb*(H2b-H1b)/(N_Pb*3)
Wtb=mdotb*(H5b-H2b)*N_Tb/3
Wb=Wtb-Wpb
H_DELTAb=H6b-H2b
H_DELTA_Sb=HS2b-HS1b
total_fuel_energyb=861966.35
nom_powerb=310000
New_powerb=Wb+nom_powerb
nicb=(nom_powerb/total_fuel_energyb)*100
n_ic_orcb=(New_powerb/total_fuel_energyb)*100
FRPb=(1-(nicb/n_ic_orcb))*100

print("enthalpy deference 6-2=",H_DELTAb)
print("enthalpy deference heat source=",H_DELTA_Sb)
print("work input=",WSb)
print("--------------------------------------------------------------")
print("mdot=",mdotb)
print("turbine work=",Wtb)
print("pump work=",Wpb)
print("cycle work=",Wb)
print("--------------------------------------------------------------")
nb=(Wb/WSb)*100
print("cycle efficiency=",nb,"%")
print("combined power=",New_powerb)
print("--------------------------------------------------------------")
print("efficency of engine=",nicb)
print("efficency of engine with orc=",n_ic_orcb)
print("Fuel Reduction Percentage=",FRPb)
     


xb=[S1b,S2b,S3b,S4b,S5b,S6b,S1b]
yb=[T1b,T2b,T3b,T4b,T5b,T6b,T1b]
PT.plot(xb,yb,marker='o',color='cyan', linestyle='dashed')
#PT.ylim(273.15,800)
#PT.xlim(0,10000)
#PT.xlabel('ENTROPY')
#PT.ylabel('TEMPERATURE')
#PT.title('TS-Diagram')
